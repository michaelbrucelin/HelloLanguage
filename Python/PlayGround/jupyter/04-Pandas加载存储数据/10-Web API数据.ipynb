# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
# Out:
# 'PERF: regression in CategoricalIndex.get_indexer'

# %%
issuse = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
issuse
# Out:
#     number                                              title  \
# 0    42249   PERF: regression in CategoricalIndex.get_indexer
# 1    42248  PERF: regression in DataFrame construction fro...
# 2    42247  PERF: regression in PeriodIndex getitem / get_loc
# 3    42246  PERF: regression in DataFrame.shift method per...
# 4    42245                  CLN: simplify MultiIndex.get_locs
# 5    42244    Updated the return type section of to_datetime
# 6    42243      PERF/ENH: allow Generator in sampling methods
# 7    42242       DOC: Add pandas-workshop community tutorial.
# 8    42241  Backport PR #42237 on branch 1.3.x (TST/CI: Re...
# 9    42240     PERF: regression in IntervalIndex intersection
# 10   42239  PERF: regression in datetimelike symmetric_dif...
# 11   42235  BUG: OutOfBoundsTimedelta not raised for out-o...
# 12   42233                           PERF/REF: groupby sample
# 13   42231       PERF: tighten _should_compare for MultiIndex
# 14   42229  BUG: to_datetime() returns object instead of d...
# 15   42227         REF: implement Index._should_partial_index
# 16   42222  ENH: add if_sheet_exists='write_to' to ExcelWr...
# 17   42221  ENH: #40231 does not allow writing multiple da...
# 18   42216  DOC: GH42204: Change docstring for head and ta...
# 19   42215  DEPR: Series.__setitem__ with Float64Index fal...
# 20   42214                 BUG: excelwriter engine_kwargs fix
# 21   42213                 DOC: add example to reorder levels
# 22   42212  ENH: Add option to make final interval closed ...
# 23   42204  Absolute value or minus sign missing in docstr...
# 24   42203  BUG: DataFrame.agg - why numpy.size doesn't work?
# 25   42198  API: combine casting behavior with extension t...
# 26   42195  PERF: Try fast/slow paths only once in DataFra...
# 27   42191               CLN: Combine checknull/checknull_old
# 28   42190  BUG: Styler.hide_columns() does not hide index...
# 29   42186  STYLE: moving spacing conventions in cython ca...
#
#                                                labels state
# 0   [{'id': 78527356, 'node_id': 'MDU6TGFiZWw3ODUy...  open
# 1   [{'id': 1465286368, 'node_id': 'MDU6TGFiZWwxND...  open
# 2   [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 3   [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 4                                                  []  open
# 5                                                  []  open
# 6   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 7                                                  []  open
# 8   [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 9   [{'id': 150096370, 'node_id': 'MDU6TGFiZWwxNTA...  open
# 10  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 11  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 12  [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNj...  open
# 13  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 14  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 15  [{'id': 1218227310, 'node_id': 'MDU6TGFiZWwxMj...  open
# 16                                                 []  open
# 17  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 18  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 19  [{'id': 87485152, 'node_id': 'MDU6TGFiZWw4NzQ4...  open
# 20                                                 []  open
# 21  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 22  [{'id': 2365504893, 'node_id': 'MDU6TGFiZWwyMz...  open
# 23  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 24  [{'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc...  open
# 25  [{'id': 1741841389, 'node_id': 'MDU6TGFiZWwxNz...  open
# 26  [{'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc...  open
# 27  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 28                                                 []  open
# 29  [{'id': 106935113, 'node_id': 'MDU6TGFiZWwxMDY...  open
