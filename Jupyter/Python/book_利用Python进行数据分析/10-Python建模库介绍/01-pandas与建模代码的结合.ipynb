# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [raw]
# 模型开发的通常工作流是使用pandas进行数据加载和清洗，然后切换到建模库进行建模。开发模型的重要一环是机器学习中的“特征工程”。它可以描述从原始数据集中提取信息的任何数据转换或分析，这些数据集可能在建模中有用。
# pandas与其它分析库通常是靠NumPy的数组联系起来的。将DataFrame转换为NumPy数组，可以使用.values属性。

# %%
data = pd.DataFrame({'x0': [1, 2, 3, 4, 5],
                     'x1': [0.01, -0.01, 0.25, -4.1, 0.],
                     'y': [-1.5, 0., 3.6, 1.3, -2.]})

display(data)
display(data.columns)
display(data.values)  # 将DataFrame转换为NumPy数组

pd.DataFrame(data.values, columns=['one', 'two', 'three'])  # 将NumPy数组转换为DataFrame
# Out:
#    x0    x1    y
# 0   1  0.01 -1.5
# 1   2 -0.01  0.0
# 2   3  0.25  3.6
# 3   4 -4.10  1.3
# 4   5  0.00 -2.0
# Index(['x0', 'x1', 'y'], dtype='object')
# array([[ 1.  ,  0.01, -1.5 ],
#        [ 2.  , -0.01,  0.  ],
#        [ 3.  ,  0.25,  3.6 ],
#        [ 4.  , -4.1 ,  1.3 ],
#        [ 5.  ,  0.  , -2.  ]])
#    one   two  three
# 0  1.0  0.01   -1.5
# 1  2.0 -0.01    0.0
# 2  3.0  0.25    3.6
# 3  4.0 -4.10    1.3
# 4  5.0  0.00   -2.0

# %% [raw]
# 最好当数据是同构化的时候使用.values属性。例如，全是数值类型。如果数据不是同构化的，结果会是Python对象的ndarray。

# %%
df3 = data.copy()
df3['string'] = ['a', 'b', 'c', 'd', 'e']
display(df3)
display(df3.values)

model_cols = ['x0', 'x1']
data.loc[:, model_cols].values
# Out:
#    x0    x1    y string
# 0   1  0.01 -1.5      a
# 1   2 -0.01  0.0      b
# 2   3  0.25  3.6      c
# 3   4 -4.10  1.3      d
# 4   5  0.00 -2.0      e
# array([[1, 0.01, -1.5, 'a'],
#        [2, -0.01, 0.0, 'b'],
#        [3, 0.25, 3.6, 'c'],
#        [4, -4.1, 1.3, 'd'],
#        [5, 0.0, -2.0, 'e']], dtype=object)
# array([[ 1.  ,  0.01],
#        [ 2.  , -0.01],
#        [ 3.  ,  0.25],
#        [ 4.  , -4.1 ],
#        [ 5.  ,  0.  ]])

# %%
data['category'] = pd.Categorical(['a', 'b', 'a', 'a', 'b'], categories=['a', 'b'])
display(data)

dummies = pd.get_dummies(data.category, prefix='category')
data_with_dummies = data.drop('category', axis=1).join(dummies)
data_with_dummies
# Out:
#    x0    x1    y category
# 0   1  0.01 -1.5        a
# 1   2 -0.01  0.0        b
# 2   3  0.25  3.6        a
# 3   4 -4.10  1.3        a
# 4   5  0.00 -2.0        b
#    x0    x1    y  category_a  category_b
# 0   1  0.01 -1.5           1           0
# 1   2 -0.01  0.0           0           1
# 2   3  0.25  3.6           1           0
# 3   4 -4.10  1.3           1           0
# 4   5  0.00 -2.0           0           1
