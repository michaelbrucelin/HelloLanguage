# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 构造Pandas并绘图

# %%
l = np.arange(100)
c1 = pd.Series(l)
c2 = pd.Series(l*np.random.randint(1, 4, len(l)))
c3 = pd.Series(l*np.random.rand(len(l)))

df = pd.DataFrame(list(zip(c1,c2,c3)))
df.plot()
# Out:
# <AxesSubplot:>
