# %%
Write-Host "hello world"
# Out:
# hello world

# %%
Get-process
# Out:
#  NPM(K)    PM(M)      WS(M)     CPU(s)      Id  SI ProcessName
#  ------    -----      -----     ------      --  -- -----------
#       0     1.82       0.74       0.00    1132 …31 (sd-pam)
#       0    18.96      15.36       1.55     682 682 /usr/sbin/smoke
#       0     0.03       4.19       0.25     446 446 accounts-daemon
#       0     0.72      19.29       4.82     623 623 apache2
#       0     1.28       6.38       0.00   61655 623 apache2
#       0     0.73       7.41       0.02   61656 623 apache2
#       0     0.72       7.51       0.00   61657 623 apache2
#       0     0.72       7.51       0.00   61658 623 apache2
#       0     0.72       7.51       0.00   61659 623 apache2
#       0     0.72       7.51       0.00   61660 623 apache2
#       0     0.72       7.51       0.00   61661 623 apache2
#       0     0.00       1.88       0.00     494 494 atd
#       0     0.08       0.23       0.00     495 449 avahi-daemon: chroot helper
# ...
